# %% [markdown]
# <a href="https://colab.research.google.com/github/gssmiles/flutter_ios_1/blob/main/Cloning_AI-SoulX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Soul-AILab/SoulX-Singer.git
# %cd SoulX-Singer
# Out:
# Cloning into 'SoulX-Singer'...
# remote: Enumerating objects: 424, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 424 (delta 55), reused 39 (delta 39), pack-reused 331 (from 1)
# Receiving objects: 100% (424/424), 17.28 MiB | 25.94 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# /content/SoulX-Singer

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -p /usr/local/miniconda
# Out:
# PREFIX=/usr/local/miniconda
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local/miniconda

# %%
import os

os.environ["PATH"] = "/usr/local/miniconda/bin:" + os.environ["PATH"]

# !conda --version
# Out:
# conda 26.3.2

# %%
# !conda create -n soulxsinger -y python=3.10
# Out:
# Jupyter detected...
#
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     - https://repo.anaconda.com/pkgs/main
#     - https://repo.anaconda.com/pkgs/r
#
# To accept these channels' Terms of Service, run the following commands:
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# For information on safely removing channels from your conda configuration,
# please see the official documentation:
#
#     https://www.anaconda.com/docs/tools/working-with-conda/channels

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# !conda tos view
# Out:
# viewing Terms of Service for https://repo.anaconda.com/pkgs/main:
# ANACONDA TERMS OF SERVICE
# Effective Date: July 15, 2025
#
# See https://anaconda.com/legal/terms/terms-of-service
# viewing Terms of Service for https://repo.anaconda.com/pkgs/r:
# ANACONDA TERMS OF SERVICE
# Effective Date: July 15, 2025
#
# See https://anaconda.com/legal/terms/terms-of-service

# %%
# !conda create -n soulxsinger -y python=3.10
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.3.2
#     latest version: 26.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/miniconda/envs/soulxsinger
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |           52_gnu           7 KB
#     ca-certificates-2026.5.14  |       h06a4308_0         107 KB
#     libexpat-2.8.1             |       h7354ed3_0         123 KB
#     libgcc-15.2.0              |       h69a1729_8         803 KB
#     libgcc-ng-15.2.0           |       h166f726_8          28 KB
# ...

# %%
# !conda run -n soulxsinger python --version
# Out:
# Python 3.10.20

# %%
# !conda run -n soulxsinger pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 98.4 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
# !conda run -n soulxsinger huggingface-cli download Soul-AILab/SoulX-Singer \
    --local-dir pretrained_models/SoulX-Singer

# !conda run -n soulxsinger huggingface-cli download Soul-AILab/SoulX-Singer-Preprocess \
    --local-dir pretrained_models/SoulX-Singer-Preprocess
# Out:
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# /content/SoulX-Singer/pretrained_models/SoulX-Singer
#
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]Downloading 'model-svc.pt' to 'pretrained_models/SoulX-Singer/.cache/huggingface/download/3K2j7qgdGNiofMgatUiOFh5giUQ=.38e72d9e15be6eef3cc937daaf81421a7b5b546816786530bb9aa346cee5d43c.incomplete'
# ...
# Download complete. Moving file to pretrained_models/SoulX-Singer/.gitattributes
#
# Fetching 7 files:  14%|█▍        | 1/7 [00:00<00:01,  5.49it/s]Download complete. Moving file to pretrained_models/SoulX-Singer/README.md
# ...
# Download complete. Moving file to pretrained_models/SoulX-Singer/config.yaml
# Download complete. Moving file to pretrained_models/SoulX-Singer/assets/soulx-logo.png
# Download complete. Moving file to pretrained_models/SoulX-Singer/assets/soul_wechat01.jpg
#
# ...

# %%
# !conda run -n soulxsinger bash example/preprocess.sh
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# Traceback (most recent call last):
#   File "/usr/local/miniconda/envs/soulxsinger/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/local/miniconda/envs/soulxsinger/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/SoulX-Singer/preprocess/pipeline.py", line 161, in <module>
#     main(args)
# ...
